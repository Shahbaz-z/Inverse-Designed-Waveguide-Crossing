# %% [markdown]
# # Waveguide demo
#
# Parametric strip waveguide cell from the PIC Component Library.

# %%
from components.waveguide import my_waveguide

wg = my_waveguide(length=20.0, width=0.45)
wg.plot()
print(wg.ports)
